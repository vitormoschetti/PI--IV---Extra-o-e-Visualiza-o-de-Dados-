# %%
import pandas as pd
import matplotlib.pyplot as plt

dados = pd.read_csv('Consumo_cerveja.csv', sep = ",")
# Out:
#                        Consumo de cerveja (litros)  Data  Final de Semana  \
# Temperatura Media (C)
# 12,9                                             1     1                1
# 14                                               1     1                1
# 14,18                                            1     1                1
# 14,52                                            1     1                1
# 14,54                                            1     1                1
# 14,66                                            1     1                1
# 14,72                                            1     1                1
# 14,82                                            1     1                1
# 14,94                                            1     1                1
# 15,26                                            1     1                1
# 15,34                                            1     1                1
# 15,48                                            1     1                1
# 15,78                                            1     1                1
# 15,82                                            1     1                1
# 15,9                                             1     1                1
# 16,02                                            1     1                1
# 16,04                                            1     1                1
# 16,1                                             2     2                2
# 16,12                                            1     1                1
# 16,14                                            1     1                1
# 16,2                                             2     2                2
# 16,22                                            1     1                1
# 16,28                                            3     3                3
# 16,34                                            1     1                1
# 16,46                                            2     2                2
# 16,48                                            1     1                1
# 16,6                                             1     1                1
# 16,66                                            1     1                1
# 16,72                                            2     2                2
# 16,76                                            2     2                2
# ...                                            ...   ...              ...
# 25,66                                            1     1                1
# 25,68                                            1     1                1
# 25,7                                             1     1                1
# 25,86                                            1     1                1
# 25,96                                            2     2                2
# 26,14                                            1     1                1
# 26,16                                            1     1                1
# 26,2                                             1     1                1
# 26,24                                            1     1                1
# 26,28                                            1     1                1
# 26,3                                             1     1                1
# 26,42                                            1     1                1
# 26,5                                             1     1                1
# 26,56                                            1     1                1
# 26,76                                            1     1                1
# 27,02                                            1     1                1
# 27,26                                            1     1                1
# 27,3                                             1     1                1
# 27,46                                            1     1                1
# 27,62                                            1     1                1
# 27,66                                            1     1                1
# 27,68                                            1     1                1
# 28                                               1     1                1
# 28,06                                            1     1                1
# 28,12                                            1     1                1
# 28,2                                             1     1                1
# 28,22                                            1     1                1
# 28,26                                            1     1                1
# 28,3                                             1     1                1
# 28,86                                            1     1                1
#
#                        Precipitacao (mm)  Temperatura Maxima (C)  \
# Temperatura Media (C)
# 12,9                                   1                       1
# 14                                     1                       1
# 14,18                                  1                       1
# 14,52                                  1                       1
# 14,54                                  1                       1
# 14,66                                  1                       1
# 14,72                                  1                       1
# 14,82                                  1                       1
# 14,94                                  1                       1
# 15,26                                  1                       1
# 15,34                                  1                       1
# 15,48                                  1                       1
# 15,78                                  1                       1
# 15,82                                  1                       1
# 15,9                                   1                       1
# 16,02                                  1                       1
# 16,04                                  1                       1
# 16,1                                   2                       2
# 16,12                                  1                       1
# 16,14                                  1                       1
# 16,2                                   2                       2
# 16,22                                  1                       1
# 16,28                                  3                       3
# 16,34                                  1                       1
# 16,46                                  2                       2
# 16,48                                  1                       1
# 16,6                                   1                       1
# 16,66                                  1                       1
# 16,72                                  2                       2
# 16,76                                  2                       2
# ...                                  ...                     ...
# 25,66                                  1                       1
# 25,68                                  1                       1
# 25,7                                   1                       1
# 25,86                                  1                       1
# 25,96                                  2                       2
# 26,14                                  1                       1
# 26,16                                  1                       1
# 26,2                                   1                       1
# 26,24                                  1                       1
# 26,28                                  1                       1
# 26,3                                   1                       1
# 26,42                                  1                       1
# 26,5                                   1                       1
# 26,56                                  1                       1
# 26,76                                  1                       1
# 27,02                                  1                       1
# 27,26                                  1                       1
# 27,3                                   1                       1
# 27,46                                  1                       1
# 27,62                                  1                       1
# 27,66                                  1                       1
# 27,68                                  1                       1
# 28                                     1                       1
# 28,06                                  1                       1
# 28,12                                  1                       1
# 28,2                                   1                       1
# 28,22                                  1                       1
# 28,26                                  1                       1
# 28,3                                   1                       1
# 28,86                                  1                       1
#
#                        Temperatura Minima (C)
# Temperatura Media (C)
# 12,9                                        1
# 14                                          1
# 14,18                                       1
# 14,52                                       1
# 14,54                                       1
# 14,66                                       1
# 14,72                                       1
# 14,82                                       1
# 14,94                                       1
# 15,26                                       1
# 15,34                                       1
# 15,48                                       1
# 15,78                                       1
# 15,82                                       1
# 15,9                                        1
# 16,02                                       1
# 16,04                                       1
# 16,1                                        2
# 16,12                                       1
# 16,14                                       1
# 16,2                                        2
# 16,22                                       1
# 16,28                                       3
# 16,34                                       1
# 16,46                                       2
# 16,48                                       1
# 16,6                                        1
# 16,66                                       1
# 16,72                                       2
# 16,76                                       2
# ...                                       ...
# 25,66                                       1
# 25,68                                       1
# 25,7                                        1
# 25,86                                       1
# 25,96                                       2
# 26,14                                       1
# 26,16                                       1
# 26,2                                        1
# 26,24                                       1
# 26,28                                       1
# 26,3                                        1
# 26,42                                       1
# 26,5                                        1
# 26,56                                       1
# 26,76                                       1
# 27,02                                       1
# 27,26                                       1
# 27,3                                        1
# 27,46                                       1
# 27,62                                       1
# 27,66                                       1
# 27,68                                       1
# 28                                          1
# 28,06                                       1
# 28,12                                       1
# 28,2                                        1
# 28,22                                       1
# 28,26                                       1
# 28,3                                        1
# 28,86                                       1
#
# [277 rows x 6 columns]

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 941 entries, 0 to 940
# Data columns (total 7 columns):
# Data                           365 non-null object
# Temperatura Media (C)          365 non-null object
# Temperatura Minima (C)         365 non-null object
# Temperatura Maxima (C)         365 non-null object
# Precipitacao (mm)              365 non-null object
# Final de Semana                365 non-null float64
# Consumo de cerveja (litros)    365 non-null float64
# dtypes: float64(2), object(5)
# memory usage: 51.5+ KB

# %%
# plt.hist(dadosTratados.consumoLitros)
# plt.title("Histograma das Médias do Consumo de Cerveja em Litros")

# %%
dadosTratados = (dados['Data'].notnull())
dadosTratados = dados[dadosTratados]
dadosTratados.columns = [ 'data', 'temperaturaMedia', 'temperaturaMinima', 'temperaturaMaxima', 'precipitacao', 'finalSemana', 'consumoLitros']

fds = {
    0 : 'Dia da Semana',
    1 : 'Final de Semana'
}

dadosTratados.finalSemana = dadosTratados.finalSemana.map(fds)


# itens = dadosTratados.shape[0]

# dadosTratados.finalSemana.unique()
# meses = {
#     '*-01-': '01'
# }
# dadosTratados.data = dadosTratados.data.map(meses)
dadosTratados['temperaturaMedia'] = dadosTratados['temperaturaMedia'].str.replace(',','.')


dadosTratados['temperaturaMedia'] = dadosTratados['temperaturaMedia'].astype(float)
dadosTratados['temperaturaMedia'] = dadosTratados['temperaturaMedia'].astype(int)
dadosTratados.head(5)
# Out:
# C:\Users\jackson\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\jackson\Anaconda3\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\jackson\Anaconda3\lib\site-packages\ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#          data  temperaturaMedia temperaturaMinima temperaturaMaxima  \
# 0  2015-01-01                27              23,9              32,5
# 1  2015-01-02                27              24,5              33,5
# 2  2015-01-03                24              22,4              29,9
# 3  2015-01-04                23              21,5              28,6
# 4  2015-01-05                23                21              28,3
#
#   precipitacao      finalSemana  consumoLitros
# 0            0    Dia da Semana         25.461
# 1            0    Dia da Semana         28.972
# 2            0  Final de Semana         30.814
# 3          1,2  Final de Semana         29.799
# 4            0    Dia da Semana         28.900

# %%
# a = []
# i = 0
# while(i < itens):
#     total = float(dadosTratados.iloc[i,1])
#     i+=1
#     diasNoMes = 0
#     data = dadosTratados.iloc[i,0]
#     dataAnterior = dadosTratados.iloc[i-1,0]
#     mes = int(data.split('-')[1])
#     mesAnterior = int(dataAnterior.split('-')[1])
    
    
    
#     while(i < itens and int(dadosTratados.iloc[i,0].split('-')[1]) == int(dadosTratados.iloc[i-1,0].split('-')[1]) ):
#         total += float(dadosTratados.iloc[i,1])
#         data = dadosTratados.iloc[i,0]
#         dataAnterior = dadosTratados.iloc[i-1,0]
#         mes = int(data.split('-')[1])
#         mesAnterior = int(dataAnterior.split('-')[1])    
#         diasNoMes += 1
#         i += 1

#     media = total/(diasNoMes+1)
#     a.append(media)
    
# a
dadosTratados.temperaturaMedia.unique()
# Out:
# array([27, 24, 23, 28, 26, 25, 21, 22, 20, 19, 17, 18, 16, 14, 15, 12],
#       dtype=int64)

# %%
import seaborn as sns
import matplotlib.pyplot as plt


plt.figure(figsize=(15,6))
sns.lineplot(y = 'consumoLitros', x = 'temperaturaMedia', data=dadosTratados)
plt.ylabel('Consumo de Cerveja em Litros')
plt.xlabel('Temperatura Média do Ambiente (C°)')
dadosTratados.head()
dadosTratados.groupby('temperaturaMedia').count().sort_index(axis= 1)
# Out:
#                   consumoLitros  data  finalSemana  precipitacao  \
# temperaturaMedia
# 12                            1     1            1             1
# 14                            8     8            8             8
# 15                            6     6            6             6
# 16                           30    30           30            30
# 17                           23    23           23            23
# 18                           23    23           23            23
# 19                           30    30           30            30
# 20                           37    37           37            37
# 21                           53    53           53            53
# 22                           50    50           50            50
# 23                           35    35           35            35
# 24                           28    28           28            28
# 25                           16    16           16            16
# 26                           10    10           10            10
# 27                            7     7            7             7
# 28                            8     8            8             8
#
#                   temperaturaMaxima  temperaturaMinima
# temperaturaMedia
# 12                                1                  1
# 14                                8                  8
# 15                                6                  6
# 16                               30                 30
# 17                               23                 23
# 18                               23                 23
# 19                               30                 30
# 20                               37                 37
# 21                               53                 53
# 22                               50                 50
# 23                               35                 35
# 24                               28                 28
# 25                               16                 16
# 26                               10                 10
# 27                                7                  7
# 28                                8                  8
